# %%
import numpy as np

# Load the .npy file
data = np.load("tasks_batch_0.npy")
print(data)
print("********")
data = np.load("tasks_batch_1.npy")
print(data)
# Out:
# [[ 1.00000000e+04  4.90000000e+01  1.80000000e+01  3.11465868e+00
#    9.40000000e+01  3.60000000e+01  2.67109921e+00  0.00000000e+00
#    1.00000000e+01  8.04000000e+01  6.40000000e+01]
#  [ 1.00010000e+04  5.10000000e+01  1.40000000e+01 -1.54272804e+00
#    4.80000000e+01  1.40000000e+01  2.07267000e+00  0.00000000e+00
#    1.00000000e+01  1.44000000e+01  4.00000000e+00]
#  [ 1.00020000e+04  4.90000000e+01  3.40000000e+01 -1.09659122e+00
#    5.60000000e+01  3.30000000e+01 -2.65430494e+00  0.00000000e+00
#    1.00000000e+01  1.99000000e+01  9.00000000e+00]
#  [ 1.00030000e+04  4.80000000e+01  1.00000000e+01 -2.04492762e+00
#    2.70000000e+01  1.30000000e+01  8.85588908e-01  0.00000000e+00
#    1.00000000e+01  3.75000000e+01  2.50000000e+01]
#  [ 1.00040000e+04  5.70000000e+01  1.00000000e+01  2.26703411e-01
#    6.00000000e+01  3.20000000e+01  1.32664742e+00  0.00000000e+00
#    1.00000000e+01  3.86000000e+01  2.60000000e+01]
# ...

# %%
data = np.load("tasks_batch_0.npy")
print(data.shape)
# Out:
# (10, 11)

# %%
data = np.load("agents_old.npy")
print(data.shape)
print(data)
print(data.dtype) 
print(data[:, 0])
print(data[:, 0].dtype)
# Out:
# (5, 4)
# [[200.          51.          16.           2.99134318]
#  [201.          43.          24.           0.40017133]
#  [202.          43.          22.          -2.28423042]
#  [203.         104.          43.           1.18676398]
#  [204.          46.          28.           0.77210431]]
# float64
# [200. 201. 202. 203. 204.]
# float64

# %%
data = np.load("agents.npy",  allow_pickle=False)
print(data.shape)
print(data)
print(data.dtype)
print(data[:, 0])
print(data[:, 0].dtype)
# Out:
# (5, 4)
# [[ 2.00000000e+02  5.00000000e+01  3.50000000e+01 -5.02998866e-01]
#  [ 2.01000000e+02  8.60000000e+01  4.10000000e+01 -2.29466426e+00]
#  [ 2.02000000e+02  4.90000000e+01  2.20000000e+01  8.80211442e-02]
#  [ 2.03000000e+02  4.80000000e+01  2.50000000e+01  2.33072876e+00]
#  [ 2.04000000e+02  4.30000000e+01  3.70000000e+01  6.63372799e-01]]
# float64
# [200. 201. 202. 203. 204.]
# float64
